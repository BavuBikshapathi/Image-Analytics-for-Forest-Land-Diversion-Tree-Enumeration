# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (8.2.27)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (3.7.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (10.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (2.3.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (0.18.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (5.9.4)
# Requirement already satisfied: py-cpuinfo in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.0)
# Requirement already satisfied: sympy in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12.1)
# Requirement already satisfied: networkx in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.5.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics) (2021.12.0)
# Requirement already satisfied: six>=1.5 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\bavub\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
model = YOLO("yolov8m.pt")
model.train(data=f"C://Users//bavub//OneDrive\Desktop//mini project2//Data//data.yaml", epochs=10, imgsz=640, augment=True,nms=True, conf=0.25, iou=0.6)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8m.pt to 'yolov8m.pt'...
# 100%|██████████| 49.7M/49.7M [00:04<00:00, 11.7MB/s]
# New https://pypi.org/project/ultralytics/8.2.31 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.27  Python-3.11.3 torch-2.3.0+cpu CPU (12th Gen Intel Core(TM) i5-1235U)
# engine\trainer: task=detect, mode=train, model=yolov8m.pt, data=C://Users//bavub//OneDrive\Desktop//mini project2//Data//data.yaml, epochs=10, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=0.25, iou=0.6, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=True, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=True, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776275  ultralytics.nn.modules.head.Detect           [1, [192, 384, 576]]
# Model summary: 295 layers, 25856899 parameters, 25856883 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs\detect\train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning C:\Users\bavub\OneDrive\Desktop\mini project2\Data\train\labels... 1664 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1664/1664 [00:03<00:00, 460.42it/s]
# train: New cache created: C:\Users\bavub\OneDrive\Desktop\mini project2\Data\train\labels.cache
# val: Scanning C:\Users\bavub\OneDrive\Desktop\mini project2\Data\valid\labels... 105 images, 0 backgrounds, 0 corrupt: 100%|██████████| 105/105 [00:00<00:00, 452.29it/s]
# val: New cache created: C:\Users\bavub\OneDrive\Desktop\mini project2\Data\valid\labels.cache
# Plotting labels to runs\detect\train\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# TensorBoard: model graph visualization added
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\train
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10         0G        2.1      3.181       2.39         37        640:   8%|▊         | 8/104 [11:54<2:28:50, 93.02s/it]

# %%
from IPython import display

# %%
display.Image(f"/content/runs/detect/train/val_batch1_pred.jpg",width=1000)

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
count = 0

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source=/content/drive/MyDrive/Data/test/images/000000_jpg.rf.915026bba24c92d05b9c2418de59a6ed.jpg conf=0.1
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Data/test/images/000000_jpg.rf.915026bba24c92d05b9c2418de59a6ed.jpg: 640x640 5 0s, 37.2ms
# Speed: 2.8ms preprocess, 37.2ms inference, 1012.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
display.Image(f"/content/runs/detect/predict/000000_jpg.rf.915026bba24c92d05b9c2418de59a6ed.jpg",width=2000)

# %%
def count_bounding_boxes(image_path):
    # Perform prediction
    results = model.predict(source=image_path, conf=0.1)

    # Count the total number of bounding boxes detected
    total_bounding_boxes = len(results[0].boxes.data)
    print(f"Total number of trees detected: {total_bounding_boxes}")
    return total_bounding_boxes

# Specify the path to the test image
test_image_path = "/content/runs/detect/predict/000000_jpg.rf.915026bba24c92d05b9c2418de59a6ed.jpg"

# Count the total bounding boxes in the test image
count_bounding_boxes(test_image_path)
# Out:
# image 1/1 /content/runs/detect/predict/000000_jpg.rf.915026bba24c92d05b9c2418de59a6ed.jpg: 640x640 3 0s, 98.9ms
# Speed: 1.7ms preprocess, 98.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Total number of trees detected: 3
# 3
